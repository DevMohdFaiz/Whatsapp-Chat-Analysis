# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# git checkout -b feature/dev
#
# git push -u origin feature/dev

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="white")
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pi

# %%
from data_extraction import load_whatsapp_file, parse_whatsapp_message, detect_chat_type, extract_chat_data

# %%
df = load_whatsapp_file('../chats/WhatsApp Chat - The Shakirs.zip', return_dataframe=True)
df.head(10)
# Out:
#          date   time sender                                            message
# 0  06/10/2024  19:19  Dad❤️                                      video omitted
# 1  06/10/2024  19:22  Dad❤️  My family, please be careful and prayerful.\nL...
# 2  06/10/2024  19:32  Mum❤️                                 Ameena yeah Allahu
# 3  06/10/2024  19:33  Mum❤️  Thanks for the fatherly advice,may Allah conti...
# 4  06/10/2024  19:34  Dad❤️                               Aameen thumma Aameen
# 5  06/10/2024  22:03   Faiz  Thank you sir\nMay Allah protect us all from t...
# 6  06/10/2024  22:07  Dad❤️                              Aameen ya RobilAlamin
# 7  12/10/2024  17:58  Dad❤️                                      video omitted
# 8  13/10/2024  06:29  Dad❤️                                      image omitted
# 9  13/10/2024  09:11  Mum❤️                                 Thanks for sharing

# %%
df.shape
# Out:
# (892, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     892 non-null    object
#  1   time     892 non-null    object
#  2   sender   892 non-null    object
#  3   message  892 non-null    object
# dtypes: object(4)
# memory usage: 28.0+ KB

# %%
print(f"Chat type: {df.attrs.get('chat_type', 'unknown')}")
print(f"Unique senders: {df['sender'].nunique()}")
print(f"Senders: {df['sender'].unique()}")
# Out:
# Chat type: group
# Unique senders: 6
# Senders: ['Dad❤️' 'Mum❤️' 'Faiz' 'codes' 'Roqibah' 'Fareed Bobo 👦']

# %%
detect_chat_type(df)
# Out:
# 'group'

# %%
from chat_analyzer import WhatsAppChatAnalyzer

# %%
# Initialize analyzer
analyzer = WhatsAppChatAnalyzer('../chats/WhatsApp Chat - The Shakirs.zip', chat_type='auto')

# %%
# Load and analyze
analyzer.load_and_parse()
analyzer.preprocess()
analyzer.enrich()
results = analyzer.analyze()

# %%
# Generate visualizations
fig = analyzer.visualize('message_frequency', by='sender')
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/ai/lib/python3.12/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File /opt/anaconda3/envs/ai/lib/python3.12/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File /opt/anaconda3/envs/ai/lib/python3.12/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array(['Dad❤️', 'Mum❤️', 'Faiz', 'Roqibah', 'codes', 'Fareed Bobo 👦'],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': '8QCGAGwAawBdAA0A', 'dtype': 'i2'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'tracegroupgap': 0},
#                'showlegend': False,
#                'template': '...',
#                'title': {'text': 'Message frequency by sender'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Sender'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'No. of messages'}}}
# })

# %%
from dotenv import load_dotenv
load_dotenv()

from ai_insights import generate_chat_summary, generate_insights, identify_topics

# %%
generate_chat_summary(df.tail(500))
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# File ~/Desktop/Client Projects/devmohdfaiz/Whatsapp-Chat-Analysis/src/ai_insights.py:29, in _call_groq_api(prompt, model, max_tokens, temperature, retries)
#      28     Groq = None
# ---> 29     print("Warning: groq package not installed. AI features will not work.")
#      32 def _get_groq_client() -> Optional['Groq']:
#
# File /opt/anaconda3/envs/ai/lib/python3.12/site-packages/groq/resources/chat/completions.py:464, in Completions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     305 """
#     306 Creates a model response for the given chat conversation.
#     307
#    (...)    462   timeout: Override the client-level default timeout for this request, in seconds
#     463 """
# --> 464 return self._post(
#     465     "/openai/v1/chat/completions",
#     466     body=maybe_transform(
#     467         {
#     468             "messages": messages,
#     469             "model": model,
#     470             "citation_options": citation_options,
#     471             "compound_custom": compound_custom,
#     472             "disable_tool_validation": disable_tool_validation,
#     473             "documents": documents,
#     474             "exclude_domains": exclude_domains,
#     475             "frequency_penalty": frequency_penalty,
#     476             "function_call": function_call,
#     477             "functions": functions,
#     478             "include_domains": include_domains,
#     479             "include_reasoning": include_reasoning,
#     480             "logit_bias": logit_bias,
#     481             "logprobs": logprobs,
#     482             "max_completion_tokens": max_completion_tokens,
#     483             "max_tokens": max_tokens,
#     484             "metadata": metadata,
#     485             "n": n,
#     486             "parallel_tool_calls": parallel_tool_calls,
#     487             "presence_penalty": presence_penalty,
#     488             "reasoning_effort": reasoning_effort,
#     489             "reasoning_format": reasoning_format,
#     490             "response_format": response_format,
#     491             "search_settings": search_settings,
#     492             "seed": seed,
#     493             "service_tier": service_tier,
#     494             "stop": stop,
#     495             "store": store,
#     496             "stream": stream,
#     497             "temperature": temperature,
#     498             "tool_choice": tool_choice,
#     499             "tools": tools,
#     500             "top_logprobs": top_logprobs,
#     501             "top_p": top_p,
#     502             "user": user,
#     503         },
#     504         completion_create_params.CompletionCreateParams,
#     505     ),
#     506     options=make_request_options(
#     507         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     508     ),
#     509     cast_to=ChatCompletion,
#     510     stream=stream or False,
#     511     stream_cls=Stream[ChatCompletionChunk],
#     512 )
#
# File /opt/anaconda3/envs/ai/lib/python3.12/site-packages/groq/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1239 opts = FinalRequestOptions.construct(
#    1240     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241 )
# -> 1242 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/ai/lib/python3.12/site-packages/groq/_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1043     log.debug("Re-raising status error")
# -> 1044     raise self._make_status_error_from_response(err.response) from None
#    1046 break
#
# APIStatusError: Error code: 413 - {'error': {'message': 'Request too large for model `llama-3.3-70b-versatile` in organization `org_01hzswfd8bfgza6cj5f47axgnc` service tier `on_demand` on tokens per minute (TPM): Limit 12000, Requested 13911, please reduce your message size and try again. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 generate_chat_summary(df.tail(500))
#
# File ~/Desktop/Client Projects/devmohdfaiz/Whatsapp-Chat-Analysis/src/ai_insights.py:35, in generate_chat_summary(df, period, model, max_messages)
#      33 """Get Groq client instance."""
#      34 if Groq is None:
# ---> 35     return None
#      37 api_key = os.getenv('GROQ_API_KEY')
#      38 if not api_key:
#
# File ~/Desktop/Client Projects/devmohdfaiz/Whatsapp-Chat-Analysis/src/ai_insights.py:33, in _call_groq_api(prompt, model, max_tokens, temperature, retries)
#      32 def _get_groq_client() -> Optional['Groq']:
# ---> 33     """Get Groq client instance."""
#      34     if Groq is None:
#      35         return None
#
# RuntimeError: Groq API call failed after 3 attempts: Error code: 413 - {'error': {'message': 'Request too large for model `llama-3.3-70b-versatile` in organization `org_01hzswfd8bfgza6cj5f47axgnc` service tier `on_demand` on tokens per minute (TPM): Limit 12000, Requested 13911, please reduce your message size and try again. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}

# %%
summary =

# Use fastest model for quick summaries
summary = generate_chat_summary(df, model='llama-3.1-8b-instant')

# Use highest quality for deep analysis
insights = generate_insights(df, model='openai/gpt-oss-120b')

# Use fast high-quality alternative
topics = identify_topics(df, model='openai/gpt-oss-20b')

# %%
insights = analyzer.get_ai_insights('summary', period='all')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from src.chat_analyzer import WhatsAppChatAnalyzer
#       3 # Initialize analyzer
#       4 analyzer = WhatsAppChatAnalyzer('../chats/WhatsApp Chat - The Shakirs.zip', chat_type='auto')
#
# ModuleNotFoundError: No module named 'src'
